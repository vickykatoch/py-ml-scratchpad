# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
X = np.array([1,2,3])
Y = np.array([1,2,3])

# %%
def costFunctionArray(x, y, theta1):
    factor = 1/(2*len(hx))
    return pow(x-y,2) * factor

# %%
def hypothesis(X,theta1):
    return X * theta1

# %%
def plotDataW(x, y, h):
    ax = plt.subplots()
    plt.plot(X, h)
    plt.scatter(x, y, c='red')
    plt.grid(color='gray', linestyle='--', linewidth=.6, axis='both', which='both', alpha=.4)
    plt.show()

# %%
def plotData(x, y):
    plt.scatter(x, y, c='red')
    plt.grid(color='gray', linestyle='--', linewidth=.6, axis='both', which='both', alpha=.4)
    plt.show()

# %%
simple()

# %%
plotData(X,Y)
