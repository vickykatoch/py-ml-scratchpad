# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
carsData=np.array([[4,6300],[4,5800],[5,5700],[5,4500],[7,4500],[7,4200],[8,4100],[9,3100],[10,2100],[11,2500],[12,2200],])
df = pd.DataFrame(carsData,columns=['Years',"Price"])

# %%
dfTrain = df[df.Years<=9]
dfTest = df[df.Years>9]
df
# Out:
#     Years  Price
# 0       4   6300
# 1       4   5800
# 2       5   5700
# 3       5   4500
# 4       7   4500
# 5       7   4200
# 6       8   4100
# 7       9   3100
# 8      10   2100
# 9      11   2500
# 10     12   2200

# %%
plt.scatter(df.Years, df.Price, c='red')
plt.grid(color='gray', linestyle='--', linewidth=.6, axis='both', which='both', alpha=.4)
plt.show()

# %%
def calcCost(hx,y,m, theta1):
    factor = 1/(2*len(hx))
    return factor * np.sum(pow(hx - y,2))

def hypothesis(X,theta1):
    return X * theta1

def plotData(x, y, h):
    ax = plt.subplots()
    plt.plot(X, h)
    plt.scatter(x, y, c='red')
    plt.grid(color='gray', linestyle='--', linewidth=.6, axis='both', which='both', alpha=.4)
    plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mean_x = df["Years"].mean()
mean_y = df["Price"].mean()
numerator = np.sum((df["Years"] - mean_x) * (df["Price"] - mean_y))
denominator = np.sum(pow((df["Years"] - mean_x) * (df["Price"] - mean_y),2))
m= numerator/denominator

# %%
df["Price"] - mean_y
# Out:
# 0     2209.090909
# 1     1709.090909
# 2     1609.090909
# 3      409.090909
# 4      409.090909
# 5      109.090909
# 6        9.090909
# 7     -990.909091
# 8    -1990.909091
# 9    -1590.909091
# 10   -1890.909091
# Name: Price, dtype: float64
