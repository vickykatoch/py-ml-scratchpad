# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %%
def plotData(x, y, xlabel, ylabel, xlim, ylim):
#     plt.subplots()
#     plt.plot(X, h)
    plt.scatter(x, y, c='red')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel) 
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.grid(color='gray', linestyle='--', linewidth=.6, axis='both', which='both', alpha=.4)
    plt.show()

# %%
data = np.genfromtxt('../data/food-cart.csv', delimiter=',')

# %%
X = data[0:,0]
Y = data[0:,1]

X0 = np.ones(len(X))

# %%
plotData(X,Y,'City Population (10K)','Profits ($10K)',[4,24],[-5,25])

# %%
x = np.array([1,2,3])

# %%
y = np.expand_dims(x, axis=0)
y.shape
x.shape
# Out:
# (3,)
